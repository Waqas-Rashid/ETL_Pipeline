# %%
# !pip install kaggle
# Out:
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73053 sha256=202e4b50c02c0f408bdec7734fa66d8e90c00bf85d169520f57fdd4d0dbc14cc
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\29\da\11\144cc25aebdaeb4931b231e25fd34b394e6a5725cbb2f50106
# Successfully built kaggle
# ...

# %%
import kaggle

# %%
# !kaggle --version
# Out:
# Kaggle API 1.5.12

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
# downloading data set from kaggle.com Zeeshan Usmani's 

api.dataset_download_file('zusmani/pakistans-largest-ecommerce-dataset', 
                          file_name = 'Pakistan Largest Ecommerce Dataset.csv', 
                          path='./')
# Out:
# True

# %%
df = pd.read_csv('Pakistan Largest Ecommerce Dataset.csv', low_memory=False)

# %%
df
# Out:
#           item_id          status created_at  \
# 0        211131.0        complete   7/1/2016
# 1        211133.0        canceled   7/1/2016
# 2        211134.0        canceled   7/1/2016
# 3        211135.0        complete   7/1/2016
# 4        211136.0  order_refunded   7/1/2016
# ...           ...             ...        ...
# 1048570       NaN             NaN        NaN
# 1048571       NaN             NaN        NaN
# 1048572       NaN             NaN        NaN
# 1048573       NaN             NaN        NaN
# 1048574       NaN             NaN        NaN
#
#                                                        sku   price  \
# 0                                        kreations_YI 06-L  1950.0
# 1        kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0
# 2                                       Ego_UP0017-999-MR0  2450.0
# 3                                           kcc_krone deal   360.0
# 4                                              BK7010400AG   555.0
# ...

# %%
 # some cleaning, re-arranging and creating sub dataframe 
df_sub = df[["item_id", "status","price","grand_total","category_name_1"]]
df_sub = df_sub.dropna()
df_sub = df_sub.sort_values(by = ['grand_total'], inplace = False, ascending = False)
#df_sub = df_sub.rename(columns={'category_name_1':'Market'}, inplace = True)
df_sub=df_sub.head(10)

# %%
df_sub
# Out:
#          item_id          status    price  grand_total    category_name_1
# 240079  508369.0        complete   8944.0   17888000.0  Mobiles & Tablets
# 239376  507556.0        canceled   8944.0   17888000.0  Mobiles & Tablets
# 239377  507557.0        canceled   8944.0   17888000.0  Mobiles & Tablets
# 239381  507561.0        canceled   8944.0   17888000.0  Mobiles & Tablets
# 239382  507562.0        canceled   8944.0   17888000.0  Mobiles & Tablets
# 240078  508368.0        complete   8944.0   17888000.0  Mobiles & Tablets
# 199381  460979.0        canceled  52635.0    1315875.0      Entertainment
# 15878   231239.0  order_refunded  54151.0    1280473.0  Mobiles & Tablets
# 15879   231240.0  order_refunded  59151.0    1280473.0  Mobiles & Tablets
# 5699    217553.0        canceled  63999.0    1279980.0  Mobiles & Tablets

# %%
import pandas as pd
# re_naming one column in our sub dataframe
df_sub.rename(columns={'category_name_1':'Market'}, inplace = True)

# %%
df_sub
# Out:
#          item_id          status    price  grand_total             Market
# 240079  508369.0        complete   8944.0   17888000.0  Mobiles & Tablets
# 239376  507556.0        canceled   8944.0   17888000.0  Mobiles & Tablets
# 239377  507557.0        canceled   8944.0   17888000.0  Mobiles & Tablets
# 239381  507561.0        canceled   8944.0   17888000.0  Mobiles & Tablets
# 239382  507562.0        canceled   8944.0   17888000.0  Mobiles & Tablets
# 240078  508368.0        complete   8944.0   17888000.0  Mobiles & Tablets
# 199381  460979.0        canceled  52635.0    1315875.0      Entertainment
# 15878   231239.0  order_refunded  54151.0    1280473.0  Mobiles & Tablets
# 15879   231240.0  order_refunded  59151.0    1280473.0  Mobiles & Tablets
# 5699    217553.0        canceled  63999.0    1279980.0  Mobiles & Tablets

# %%
#Saving data in a CSV file.
df_sub.to_csv("Top10_startups.csv", index = False)
